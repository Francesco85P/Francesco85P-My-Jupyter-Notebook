# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Francesco Paparazzo**
#
# Actual occupation: Science Teacher; Desired occupation: Data Analyst

# %% [markdown]
# *I am interested in data science because I like to analyze data and use statistic and modelling to find out interesting and useful information and help solving problems*

# %% [markdown]
# ### My code in the next cell is supposed to give the factorial of 10

# %%
import math
print(math.factorial(10))
# Out:
# 3628800

# %% [markdown]
# Below an horizontal rule:
#
# ***
#
# Below a bullet list:
#
# - A
# - B
# - C
#
# Below a numbered list:
#
# 1. A
# 2. B
# 3. C
#
# Below a table:
#
# |Yesterday|Today|Tomorrow|
# |------|------ |------   |
# |Monday|Tuesday|Wednesdy |
# |    8 |  9    |  10     |
#
#
# Below an image (the Phyton Logo)
# ![](https://www.python.org/static/community_logos/python-logo-master-v3-TM.png "Python Logo")
#
# Below hyperlink to the Phyton website:
#
# https://www.python.org
#
# Below a code/syntax highlighting:
#
# ```python
# print(3+1)
# ```
#
# Below a strikethrough:
#
# ~~To scratch~~
#
# Below a blockquote:
#
# > Blockquote
